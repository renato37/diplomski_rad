# %%
import pandas as pd

from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df["Sex"].unique()
for col in df.columns:
    if(not is_numeric_dtype(df[col])):
        df[col]=df[col].replace(set(df[col]),list(range(len(set(df[col])))))
        print(col)
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              2        140          289          0           2
# 1     49    0              3        160          180          0           2
# 2     37    1              2        130          283          0           1
# 3     48    0              0        138          214          0           2
# 4     54    1              3        150          195          0           2
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              1        110          264          0           2
# 914   68    1              0        144          193          1           2
# 915   57    1              0        130          131          0           2
# 916   57    0              2        130          236          0           0
# 917   38    1              3        138          175          0           2
#
# ...

# %%
df.iloc[:, :6].describe().applymap(lambda x: f"{x:0.2f}").to_latex()
# Out:
# C:\Users\RenatoCiz\AppData\Local\Temp\ipykernel_33544\3291776277.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df.iloc[:, :6].describe().applymap(lambda x: f"{x:0.2f}").to_latex()
# ...

# %%
df.iloc[:, 6:12].describe().applymap(lambda x: f"{x:0.2f}").to_latex()
# Out:
# C:\Users\RenatoCiz\AppData\Local\Temp\ipykernel_33544\2745157407.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df.iloc[:, 6:12].describe().applymap(lambda x: f"{x:0.2f}").to_latex()
# ...
