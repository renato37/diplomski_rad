# %%
import tensorflow_decision_forests as tfdf

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import tensorflow as tf
import math

import dtreeviz

from matplotlib import pyplot as plt
from IPython import display
# Out:
# 2023-04-30 13:00:52.768410: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-30 13:00:52.972243: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-30 13:00:52.972946: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 13:00:54.237943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# avoid "Arial font not found warnings"
import logging
logging.getLogger('matplotlib.font_manager').setLevel(level=logging.CRITICAL)

display.set_matplotlib_formats('retina') # generate hires plots

np.random.seed(1234)  # reproducible plots/data for explanatory reasons
# Out:
# /tmp/ipykernel_85/745931794.py:5: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`

# %%
# Split the dataset into a training and a testing dataset.

def split_dataset(dataset, test_ratio=0.30):
  """Splits a panda dataframe in two."""
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

# %%
df = pd.read_csv('Covid_data.csv', sep=",")

# %%
train_ds_pd, test_ds_pd = split_dataset(df)
print("{} examples in training, {} examples for testing.".format(
    len(train_ds_pd), len(test_ds_pd)))
# Out:
# 733611 examples in training, 314964 examples for testing.

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# 1                1   72        97         2  ...       2        2
# 2                2   55        97         1  ...       2        2
# 3                2   53         2         2  ...       2        2
# 4                2   68        97         1  ...       2        2
# ...            ...  ...       ...       ...  ...     ...      ...
# 1048570          2   40        97         2  ...       2        2
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU
# 0              2                     3   97
# 1              2                     5   97
# 2              2                     3    2
# 3              2                     7   97
# 4              2                     3   97
# ...          ...                   ...  ...
# 1048570        2                     7   97
# 1048571        2                     7    2
# 1048572        2                     7   97
# 1048573        2                     7   97
# 1048574        2                     7   97
#
# [1048575 rows x 21 columns]

# %%
target = 'target'

classes = list(df[target].unique())

df[target] = df[target].map(classes.index)

# %%
# Split into training and test sets
train_ds_pd, test_ds_pd = split_dataset(df)
print(f"{len(train_ds_pd)} examples in training, {len(test_ds_pd)} examples for testing.")

# Convert to tensorflow data sets
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_ds_pd, label=target)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_ds_pd, label=target)
# Out:
# 687 examples in training, 338 examples for testing.

# %%
# Specify the model.
model_1 = tfdf.keras.RandomForestModel()

# Train the model.
model_1.fit(train_ds, validation_data=test_ds)
# Out:
# Use /tmp/tmpo9d6m4al as temporary training directory
# Reading training dataset...
# 2023-04-26 08:20:54.117669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_13' with dtype int64 and shape [687]
# 	 [[{{node Placeholder/_13}}]]
# Training dataset read in 0:00:04.963204. Found 687 examples.
# Reading validation dataset...
# 2023-04-26 08:20:59.056320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype int64 and shape [338]
# 	 [[{{node Placeholder/_7}}]]
# Num validation examples: tf.Tensor(338, shape=(), dtype=int32)
# Validation dataset read in 0:00:03.288236. Found 338 examples.
# Training model...
# Model trained in 0:00:08.089782
# Compiling model...
# [INFO 23-04-26 08:21:10.3272 CEST kernel.cc:1242] Loading model from path /tmp/tmpo9d6m4al/model/ with prefix c0473095a8884aa8
# [INFO 23-04-26 08:21:10.4232 CEST decision_forest.cc:660] Model loaded with 300 root(s), 24422 node(s), and 13 input feature(s).
# [INFO 23-04-26 08:21:10.4235 CEST abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 23-04-26 08:21:10.4235 CEST kernel.cc:1074] Use fast generic engine
# 2023-04-26 08:21:10.683996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_6' with dtype double and shape [687]
# 	 [[{{node Placeholder/_6}}]]
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7ff6b6573160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7ff6b6573160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7ff6b6573160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
model_1.compile(metrics=["accuracy"])
evaluation = model_1.evaluate(test_ds, return_dict=True)
print()

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 0.9438
#
# loss: 0.0000
# accuracy: 0.9438

# %%
model_1.save("/tmp/my_saved_model")
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves, _update_step_xla while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/my_saved_model/assets
# INFO:tensorflow:Assets written to: /tmp/my_saved_model/assets

# %%
model_1.summary()
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (13):
# 	age
# 	ca
# 	chol
# 	cp
# 	exang
# 	fbs
# 	oldpeak
# 	restecg
# 	sex
# 	slope
# 	thal
# 	thalach
# 	trestbps
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.       "cp"  0.294385 ################
#     2.     "thal"  0.243481 ##########
#     3.       "ca"  0.234838 #########
#     4.  "oldpeak"  0.210699 #######
#     5.  "thalach"  0.196582 #####
#     6.      "age"  0.181287 ####
#     7.    "exang"  0.166425 ##
#     8.     "chol"  0.163806 ##
#     9.      "sex"  0.163708 ##
#    10. "trestbps"  0.161703 #
#    11.    "slope"  0.161631 #
#    12.  "restecg"  0.144314
#    13.      "fbs"  0.142839
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "cp" 111.000000 ################
#     2.    "thal" 78.000000 ###########
#     3.      "ca" 47.000000 ######
#     4.   "exang" 22.000000 ###
#     5. "oldpeak" 21.000000 ##
#     6. "thalach" 12.000000 #
#     7.   "slope"  7.000000
#     8.     "age"  1.000000
#     9.     "sex"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.      "age" 1738.000000 ################
#     2.  "thalach" 1735.000000 ###############
#     3.     "chol" 1635.000000 ##############
#     4.  "oldpeak" 1489.000000 #############
#     5. "trestbps" 1246.000000 ###########
#     6.       "ca" 853.000000 #######
#     7.       "cp" 839.000000 ######
#     8.     "thal" 696.000000 #####
#     9.      "sex" 477.000000 ###
#    10.    "slope" 442.000000 ##
#    11.  "restecg" 399.000000 ##
#    12.    "exang" 363.000000 ##
#    13.      "fbs" 149.000000
#
# Variable Importance: SUM_SCORE:
#     1.       "cp" 22110.533990 ################
#     2.     "thal" 16133.400093 ###########
#     3.  "oldpeak" 15032.300862 ##########
#     4.       "ca" 14917.585425 ##########
#     5.  "thalach" 13353.078614 #########
#     6.      "age" 12172.959227 ########
#     7.     "chol" 9242.037459 ######
#     8. "trestbps" 7105.717540 ####
#     9.    "exang" 5324.052473 ###
#    10.      "sex" 4612.516899 ##
#    11.    "slope" 4468.338094 ##
#    12.  "restecg" 2147.192762 #
#    13.      "fbs" 731.101388
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.965065 logloss:0.166357
# Number of trees: 300
# Total number of nodes: 24422
#
# Number of nodes by tree:
# Count: 300 Average: 81.4067 StdDev: 5.86356
# Min: 65 Max: 97 Ignored: 0
# ----------------------------------------------
# [ 65, 66)  2   0.67%   0.67%
# [ 66, 68)  0   0.00%   0.67%
# [ 68, 69)  0   0.00%   0.67%
# [ 69, 71)  5   1.67%   2.33% #
# [ 71, 73)  5   1.67%   4.00% #
# [ 73, 74) 17   5.67%   9.67% ####
# [ 74, 76) 21   7.00%  16.67% #####
# [ 76, 78) 37  12.33%  29.00% #########
# [ 78, 79)  0   0.00%  29.00%
# [ 79, 81) 39  13.00%  42.00% #########
# [ 81, 83) 42  14.00%  56.00% ##########
# [ 83, 84) 39  13.00%  69.00% #########
# [ 84, 86) 31  10.33%  79.33% #######
# [ 86, 88) 22   7.33%  86.67% #####
# [ 88, 89)  0   0.00%  86.67%
# [ 89, 91) 16   5.33%  92.00% ####
# [ 91, 93)  7   2.33%  94.33% ##
# [ 93, 94) 10   3.33%  97.67% ##
# [ 94, 96)  6   2.00%  99.67% #
# [ 96, 97]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 12361 Average: 6.19375 StdDev: 1.68383
# Min: 2 Max: 14 Ignored: 0
# ----------------------------------------------
# [  2,  3)   18   0.15%   0.15%
# [  3,  4)  426   3.45%   3.59% #
# [  4,  5) 1393  11.27%  14.86% #####
# [  5,  6) 2672  21.62%  36.48% #########
# [  6,  7) 2938  23.77%  60.25% ##########
# [  7,  8) 2373  19.20%  79.44% ########
# [  8,  9) 1413  11.43%  90.87% #####
# [  9, 10)  720   5.82%  96.70% ##
# [ 10, 11)  272   2.20%  98.90% #
# [ 11, 12)   82   0.66%  99.56%
# [ 12, 13)   36   0.29%  99.85%
# [ 13, 14)   14   0.11%  99.97%
# [ 14, 14]    4   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 12361 Average: 16.6734 StdDev: 23.2047
# Min: 5 Max: 180 Ignored: 0
# ----------------------------------------------
# [   5,  13) 8577  69.39%  69.39% ##########
# [  13,  22) 1566  12.67%  82.06% ##
# [  22,  31)  688   5.57%  87.62% #
# [  31,  40)  426   3.45%  91.07%
# [  40,  49)  241   1.95%  93.02%
# [  49,  57)  142   1.15%  94.17%
# [  57,  66)   93   0.75%  94.92%
# [  66,  75)  103   0.83%  95.75%
# [  75,  84)   96   0.78%  96.53%
# [  84,  93)   99   0.80%  97.33%
# [  93, 101)   57   0.46%  97.79%
# [ 101, 110)   53   0.43%  98.22%
# [ 110, 119)   59   0.48%  98.70%
# [ 119, 128)   36   0.29%  98.99%
# [ 128, 137)   32   0.26%  99.25%
# [ 137, 145)   22   0.18%  99.43%
# [ 145, 154)   24   0.19%  99.62%
# [ 154, 163)   29   0.23%  99.85%
# [ 163, 172)   13   0.11%  99.96%
# [ 172, 180]    5   0.04% 100.00%
#
# Attribute in nodes:
# 	1738 : age [NUMERICAL]
# 	1735 : thalach [NUMERICAL]
# 	1635 : chol [NUMERICAL]
# 	1489 : oldpeak [NUMERICAL]
# 	1246 : trestbps [NUMERICAL]
# 	853 : ca [NUMERICAL]
# 	839 : cp [NUMERICAL]
# 	696 : thal [NUMERICAL]
# 	477 : sex [NUMERICAL]
# 	442 : slope [NUMERICAL]
# 	399 : restecg [NUMERICAL]
# 	363 : exang [NUMERICAL]
# 	149 : fbs [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	111 : cp [NUMERICAL]
# 	78 : thal [NUMERICAL]
# 	47 : ca [NUMERICAL]
# 	22 : exang [NUMERICAL]
# 	21 : oldpeak [NUMERICAL]
# 	12 : thalach [NUMERICAL]
# 	7 : slope [NUMERICAL]
# 	1 : sex [NUMERICAL]
# 	1 : age [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	212 : cp [NUMERICAL]
# 	172 : thal [NUMERICAL]
# 	159 : ca [NUMERICAL]
# 	112 : oldpeak [NUMERICAL]
# 	62 : thalach [NUMERICAL]
# 	61 : exang [NUMERICAL]
# 	48 : slope [NUMERICAL]
# 	35 : age [NUMERICAL]
# 	24 : sex [NUMERICAL]
# 	11 : trestbps [NUMERICAL]
# 	3 : chol [NUMERICAL]
# 	1 : restecg [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	334 : cp [NUMERICAL]
# 	298 : oldpeak [NUMERICAL]
# 	292 : ca [NUMERICAL]
# 	289 : thal [NUMERICAL]
# 	215 : thalach [NUMERICAL]
# 	142 : age [NUMERICAL]
# 	116 : slope [NUMERICAL]
# 	114 : exang [NUMERICAL]
# 	98 : sex [NUMERICAL]
# 	86 : trestbps [NUMERICAL]
# 	75 : chol [NUMERICAL]
# 	18 : restecg [NUMERICAL]
# 	5 : fbs [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	552 : oldpeak [NUMERICAL]
# 	499 : thalach [NUMERICAL]
# 	464 : cp [NUMERICAL]
# 	435 : ca [NUMERICAL]
# 	408 : thal [NUMERICAL]
# 	392 : age [NUMERICAL]
# 	308 : chol [NUMERICAL]
# 	255 : trestbps [NUMERICAL]
# 	210 : sex [NUMERICAL]
# 	193 : slope [NUMERICAL]
# 	186 : exang [NUMERICAL]
# 	86 : restecg [NUMERICAL]
# 	32 : fbs [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1234 : thalach [NUMERICAL]
# 	1146 : age [NUMERICAL]
# 	1138 : oldpeak [NUMERICAL]
# 	1035 : chol [NUMERICAL]
# 	843 : trestbps [NUMERICAL]
# 	700 : ca [NUMERICAL]
# 	677 : cp [NUMERICAL]
# 	613 : thal [NUMERICAL]
# 	403 : sex [NUMERICAL]
# 	346 : slope [NUMERICAL]
# 	292 : exang [NUMERICAL]
# 	270 : restecg [NUMERICAL]
# 	100 : fbs [NUMERICAL]
#
# Condition type in nodes:
# 	12061 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2082 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4020 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	8797 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.865854 logloss:4.83512
# 	trees: 11, Out-of-bag evaluation: accuracy:0.88774 logloss:1.08144
# 	trees: 21, Out-of-bag evaluation: accuracy:0.922853 logloss:0.289962
# 	trees: 31, Out-of-bag evaluation: accuracy:0.930131 logloss:0.238115
# 	trees: 41, Out-of-bag evaluation: accuracy:0.94032 logloss:0.180769
# 	trees: 51, Out-of-bag evaluation: accuracy:0.941776 logloss:0.175828
# 	trees: 61, Out-of-bag evaluation: accuracy:0.944687 logloss:0.175421
# 	trees: 71, Out-of-bag evaluation: accuracy:0.949054 logloss:0.172559
# 	trees: 81, Out-of-bag evaluation: accuracy:0.950509 logloss:0.17252
# 	trees: 91, Out-of-bag evaluation: accuracy:0.949054 logloss:0.171648
# 	trees: 101, Out-of-bag evaluation: accuracy:0.951965 logloss:0.172853
# 	trees: 111, Out-of-bag evaluation: accuracy:0.951965 logloss:0.17064
# 	trees: 121, Out-of-bag evaluation: accuracy:0.951965 logloss:0.170518
# 	trees: 131, Out-of-bag evaluation: accuracy:0.953421 logloss:0.168693
# 	trees: 141, Out-of-bag evaluation: accuracy:0.953421 logloss:0.169126
# 	trees: 151, Out-of-bag evaluation: accuracy:0.957787 logloss:0.168308
# 	trees: 161, Out-of-bag evaluation: accuracy:0.965065 logloss:0.168033
# 	trees: 171, Out-of-bag evaluation: accuracy:0.965065 logloss:0.1681
# 	trees: 181, Out-of-bag evaluation: accuracy:0.962154 logloss:0.167921
# 	trees: 191, Out-of-bag evaluation: accuracy:0.960699 logloss:0.166901
# 	trees: 202, Out-of-bag evaluation: accuracy:0.960699 logloss:0.167126
# 	trees: 212, Out-of-bag evaluation: accuracy:0.962154 logloss:0.166841
# 	trees: 222, Out-of-bag evaluation: accuracy:0.96361 logloss:0.166348
# 	trees: 232, Out-of-bag evaluation: accuracy:0.96361 logloss:0.166012
# 	trees: 242, Out-of-bag evaluation: accuracy:0.959243 logloss:0.166697
# 	trees: 252, Out-of-bag evaluation: accuracy:0.960699 logloss:0.166865
# 	trees: 262, Out-of-bag evaluation: accuracy:0.960699 logloss:0.167398
# 	trees: 272, Out-of-bag evaluation: accuracy:0.96361 logloss:0.166683
# 	trees: 282, Out-of-bag evaluation: accuracy:0.966521 logloss:0.166153
# 	trees: 292, Out-of-bag evaluation: accuracy:0.967977 logloss:0.165897
# 	trees: 300, Out-of-bag evaluation: accuracy:0.965065 logloss:0.166357

# %%
# The input features
model_1.make_inspector().features()
# Out:
# ["age" (1; #1),
#  "ca" (1; #2),
#  "chol" (1; #3),
#  "cp" (1; #4),
#  "exang" (1; #5),
#  "fbs" (1; #6),
#  "oldpeak" (1; #7),
#  "restecg" (1; #8),
#  "sex" (1; #9),
#  "slope" (1; #10),
#  "thal" (1; #11),
#  "thalach" (1; #12),
#  "trestbps" (1; #13)]

# %%
# The feature importances
model_1.make_inspector().variable_importances()
# Out:
# {'INV_MEAN_MIN_DEPTH': [("cp" (1; #4), 0.29438522169382536),
#   ("thal" (1; #11), 0.24348055366467178),
#   ("ca" (1; #2), 0.2348375493812727),
#   ("oldpeak" (1; #7), 0.21069914912620683),
#   ("thalach" (1; #12), 0.19658158638413753),
#   ("age" (1; #1), 0.18128702295368124),
#   ("exang" (1; #5), 0.16642538432986412),
#   ("chol" (1; #3), 0.163806244749933),
#   ("sex" (1; #9), 0.16370800717711784),
#   ("trestbps" (1; #13), 0.16170334288558721),
#   ("slope" (1; #10), 0.16163104198552056),
#   ("restecg" (1; #8), 0.14431408143199986),
#   ("fbs" (1; #6), 0.1428390954897158)],
#  'NUM_AS_ROOT': [("cp" (1; #4), 111.0),
#   ("thal" (1; #11), 78.0),
#   ("ca" (1; #2), 47.0),
#   ("exang" (1; #5), 22.0),
#   ("oldpeak" (1; #7), 21.0),
#   ("thalach" (1; #12), 12.0),
#   ("slope" (1; #10), 7.0),
#   ("age" (1; #1), 1.0),
#   ("sex" (1; #9), 1.0)],
#  'SUM_SCORE': [("cp" (1; #4), 22110.53399033565),
#   ("thal" (1; #11), 16133.400092552416),
#   ("oldpeak" (1; #7), 15032.300861702766),
#   ("ca" (1; #2), 14917.585425066762),
#   ("thalach" (1; #12), 13353.078614367289),
#   ("age" (1; #1), 12172.959227033949),
#   ("chol" (1; #3), 9242.037459098268),
#   ("trestbps" (1; #13), 7105.717539731413),
#   ("exang" (1; #5), 5324.05247328151),
#   ("sex" (1; #9), 4612.51689926954),
#   ("slope" (1; #10), 4468.338093844708),
#   ("restecg" (1; #8), 2147.1927617553156),
#   ("fbs" (1; #6), 731.1013884055428)],
#  'NUM_NODES': [("age" (1; #1), 1738.0),
#   ("thalach" (1; #12), 1735.0),
#   ("chol" (1; #3), 1635.0),
#   ("oldpeak" (1; #7), 1489.0),
#   ("trestbps" (1; #13), 1246.0),
#   ("ca" (1; #2), 853.0),
#   ("cp" (1; #4), 839.0),
#   ("thal" (1; #11), 696.0),
#   ("sex" (1; #9), 477.0),
#   ("slope" (1; #10), 442.0),
#   ("restecg" (1; #8), 399.0),
#   ("exang" (1; #5), 363.0),
#   ("fbs" (1; #6), 149.0)]}

# %%
# Tell dtreeviz about training data and model
features = [f.name for f in model_1.make_inspector().features()]
viz_cmodel = dtreeviz.model(model_1,
                           tree_index=3,
                           X_train=train_ds_pd[features],
                           y_train=train_ds_pd[target],
                           feature_names=features,
                           target_name=target,
                           class_names=classes)

# %%
viz_cmodel.view(scale=1.2)

# %%
print(features)
# Out:
# ['age', 'ca', 'chol', 'cp', 'exang', 'fbs', 'oldpeak', 'restecg', 'sex', 'slope', 'thal', 'thalach', 'trestbps']

# %%
model_1.save("my_model")
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves, _update_step_xla while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_model/assets
# INFO:tensorflow:Assets written to: my_model/assets

# %%
df.head(1)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
#
#    ca  thal  target
# 0   2     3       0

# %% [markdown]
# df[~'infectionProb']

# %%
test = tfdf.keras.pd_dataframe_to_tf_dataset(df.loc[:, df.columns!='target'].head(1))
t1 = df['target'].head(1)

# %%
tes = model_1.predict(test, verbose=0)
# Out:
# 2023-04-26 08:25:21.836019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_8' with dtype int64 and shape [1]
# 	 [[{{node Placeholder/_8}}]]

# %%
k = []
i = 0
cnt = 0
for t in tes:
    if(t[0]>0.50):
        k.append(1)
        #print("1 - " + str(t1[i]))
        if(t1[i] == 1):
            cnt += 1
    else:
        k.append(0)
        #print("0 - " + str(t1[i]))
        if(t1[i] == 0):
            cnt += 1
    i+=1
print(cnt/len(t1))
# Out:
# 1.0

# %%
print(df.head(1))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
#
#    ca  thal  target
# 0   2     3       0

# %%
t2_dic = {'age':[103], 'cp': [0], 'fbs':[1], 'thalach ':[170]}
t2_df = pd.DataFrame.from_dict(t2_dic)

# %%
d2_tfdf = tfdf.keras.pd_dataframe_to_tf_dataset(t2_df)
# Out:
# Warning: Some of the feature names have been changed automatically to be compatible with SavedModels because fix_feature_names=True.
# WARNING:absl:Some of the feature names have been changed automatically to be compatible with SavedModels because fix_feature_names=True.

# %%
model_1.predict(d2_tfdf, verbose=0)
# Out:
# 2023-04-26 08:26:03.860535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [1]
# 	 [[{{node Placeholder/_3}}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 model_1.predict(d2_tfdf, verbose=0)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_file81hjbu2x.py:43, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function_trained(iterator, model)
#      41 try:
#      42     do_return = True
# ---> 43     retval_ = ag__.converted_call(ag__.ld(run_step), (ag__.ld(data),), None, fscope)
#      44 except:
#      45     do_return = False
#
# File /tmp/__autograph_generated_file81hjbu2x.py:30, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function_trained.<locals>.run_step(data)
#      28 do_return_1 = False
#      29 retval__1 = ag__.UndefinedReturnValue()
# ---> 30 outputs = ag__.converted_call(ag__.ld(model).predict_step, (ag__.ld(data),), None, fscope_1)
#      31 with ag__.ld(tf).control_dependencies(ag__.ld(_minimum_control_deps)(ag__.ld(outputs))):
#      32     ag__.converted_call(ag__.ld(model)._predict_counter.assign_add, (1,), None, fscope_1)
#
# File /tmp/__autograph_generated_filexwwlsd2w.py:104, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, inputs, training)
#     102 multitask_item = ag__.Undefined('multitask_item')
#     103 predictions = ag__.Undefined('predictions')
# --> 104 ag__.if_stmt(ag__.ld(self)._semantics is None, if_body_2, else_body_2, get_state_3, set_state_3, ('do_return', 'retval_'), 2)
#     105 return fscope.ret(retval_, do_return)
#
# File /tmp/__autograph_generated_filexwwlsd2w.py:43, in outer_factory.<locals>.inner_factory.<locals>.tf__call.<locals>.else_body_2()
#      41 def else_body_2():
#      42     nonlocal do_return, retval_
# ---> 43     normalized_inputs = ag__.converted_call(ag__.ld(self)._build_normalized_inputs, (ag__.ld(inputs),), None, fscope)
#      44     predictions = {}
#      46     def get_state():
#
# File /tmp/__autograph_generated_filel5i3o27u.py:98, in outer_factory.<locals>.inner_factory.<locals>.tf___build_normalized_inputs(self, inputs)
#      96     ag__.if_stmt(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(inputs), ag__.ld(tf).Tensor), None, fscope), if_body_3, else_body_3, get_state_3, set_state_3, ('inputs',), 1)
#      97 ag__.if_stmt(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(inputs), ag__.ld(dict)), None, fscope), if_body_4, else_body_4, get_state_4, set_state_4, ('inputs',), 1)
# ---> 98 semantic_inputs = ag__.converted_call(ag__.ld(tf_core).combine_tensors_and_semantics, (ag__.ld(inputs), ag__.ld(self)._semantics), None, fscope)
#      99 normalized_semantic_inputs = ag__.converted_call(ag__.ld(tf_core).normalize_inputs, (ag__.ld(semantic_inputs),), dict(categorical_integer_offset_correction=ag__.not_(ag__.ld(self)._advanced_arguments.disable_categorical_integer_offset_correction)), fscope)
#     100 (normalized_inputs, _) = ag__.converted_call(ag__.ld(tf_core).decombine_tensors_and_semantics, (ag__.ld(normalized_semantic_inputs),), None, fscope)
#
# File /tmp/__autograph_generated_filek1wz0kwj.py:34, in outer_factory.<locals>.inner_factory.<locals>.tf__combine_tensors_and_semantics(inputs, semantics)
#      32 def else_body():
#      33     pass
# ---> 34 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.converted_call(ag__.ld(set), (ag__.converted_call(ag__.ld(semantics).keys, (), None, fscope),), None, fscope).issubset, (ag__.converted_call(ag__.ld(inputs).keys, (), None, fscope),), None, fscope)), if_body, else_body, get_state, set_state, (), 0)
#      35 semantic_tensors = {}
#      37 def get_state_1():
#
# File /tmp/__autograph_generated_filek1wz0kwj.py:30, in outer_factory.<locals>.inner_factory.<locals>.tf__combine_tensors_and_semantics.<locals>.if_body()
#      29 def if_body():
# ---> 30     raise ag__.converted_call(ag__.ld(ValueError), (ag__.converted_call('semantics is not a subset of inputs (inputs={} vs semantics={}).'.format, (ag__.converted_call(ag__.ld(inputs).keys, (), None, fscope), ag__.converted_call(ag__.ld(semantics).keys, (), None, fscope)), None, fscope),), None, fscope)
#
# ValueError: in user code:
#
#     File "/home/renato/anaconda3/lib/python3.9/site-packages/tensorflow_decision_forests/keras/core_inference.py", line 458, in run_step  *
#         outputs = model.predict_step(data)
#     File "/home/renato/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 2111, in predict_step  **
#         return self(x, training=False)
#     File "/home/renato/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/tmp/__autograph_generated_filexwwlsd2w.py", line 104, in tf__call
#         ag__.if_stmt(ag__.ld(self)._semantics is None, if_body_2, else_body_2, get_state_3, set_state_3, ('do_return', 'retval_'), 2)
#     File "/tmp/__autograph_generated_filexwwlsd2w.py", line 43, in else_body_2
#         normalized_inputs = ag__.converted_call(ag__.ld(self)._build_normalized_inputs, (ag__.ld(inputs),), None, fscope)
#     File "/tmp/__autograph_generated_filel5i3o27u.py", line 98, in tf___build_normalized_inputs
#         semantic_inputs = ag__.converted_call(ag__.ld(tf_core).combine_tensors_and_semantics, (ag__.ld(inputs), ag__.ld(self)._semantics), None, fscope)
#     File "/tmp/__autograph_generated_filek1wz0kwj.py", line 34, in tf__combine_tensors_and_semantics
#         ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.converted_call(ag__.ld(set), (ag__.converted_call(ag__.ld(semantics).keys, (), None, fscope),), None, fscope).issubset, (ag__.converted_call(ag__.ld(inputs).keys, (), None, fscope),), None, fscope)), if_body, else_body, get_state, set_state, (), 0)
#     File "/tmp/__autograph_generated_filek1wz0kwj.py", line 30, in if_body
#         raise ag__.converted_call(ag__.ld(ValueError), (ag__.converted_call('semantics is not a subset of inputs (inputs={} vs semantics={}).'.format, (ag__.converted_call(ag__.ld(inputs).keys, (), None, fscope), ag__.converted_call(ag__.ld(semantics).keys, (), None, fscope)), None, fscope),), None, fscope)
#
#     ValueError: Exception encountered when calling layer 'random_forest_model' (type RandomForestModel).
#
#     in user code:
#
#         File "/home/renato/anaconda3/lib/python3.9/site-packages/tensorflow_decision_forests/keras/core_inference.py", line 644, in call  *
#             normalized_inputs = self._build_normalized_inputs(inputs)
#         File "/home/renato/anaconda3/lib/python3.9/site-packages/tensorflow_decision_forests/keras/core_inference.py", line 603, in _build_normalized_inputs  *
#             semantic_inputs = tf_core.combine_tensors_and_semantics(
#         File "/home/renato/anaconda3/lib/python3.9/site-packages/tensorflow_decision_forests/tensorflow/core_inference.py", line 431, in combine_tensors_and_semantics  *
#             raise ValueError("semantics is not a subset of inputs "
#
#         ValueError: semantics is not a subset of inputs (inputs=dict_keys(['age', 'cp', 'fbs', 'thalach_']) vs semantics=dict_keys(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal'])).
#
#
#     Call arguments received by layer 'random_forest_model' (type RandomForestModel):
#       • inputs={'age': 'tf.Tensor(shape=(None,), dtype=int64)', 'cp': 'tf.Tensor(shape=(None,), dtype=int64)', 'fbs': 'tf.Tensor(shape=(None,), dtype=int64)', 'thalach_': 'tf.Tensor(shape=(None,), dtype=int64)'}
#       • training=False
